# %% [markdown]
# <h1>Chapter 1 - RAG Setup</h1><i>Building your first RAG (Retrieval Augmented Generation) system.</i><a>
#
# <a href="https://learning.oreilly.com/library/view/rag-with-python/9798341600553/"><img src="https://img.shields.io/badge/O'Reilly-white.svg?logo=..."></a>
# <a href="https://github.com/polzerdo55862/RAG-with-Python-Cookbook"><img src="https://img.shields.io/badge/GitHub%20Repository-black?logo=github"></a>
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/polzerdo55862/RAG-with-Python-Cookbook/blob/main/ch01_RAG_intro/rag_basics.ipynb)
#
# ---
#
# This notebook is for Chapter 1 of the [RAG with Python Cookbook](https://learning.oreilly.com/library/view/rag-with-python/9798341600553/) book by [Dominik Polzer](https://www.linkedin.com/in/polzerdo/).
#
# ---
#
# <a href="https://learning.oreilly.com/library/view/rag-with-python/9798341600553/">
#   <img src="https://raw.githubusercontent.com/polzerdo55862/RAG-with-Python-Cookbook/main/rag_cookbook.png" width="350" />
# </a>

# %% [markdown]
# ## Install Required Packages

# %%
# %pip install "numpy<2" openai==1.12.0 chromadb==0.4.22 tiktoken==0.5.2 python-dotenv==1.0.0
# Out:
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Requirement already satisfied: openai==1.12.0 in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: chromadb==0.4.22 in /usr/local/lib/python3.12/dist-packages (0.4.22)
# Requirement already satisfied: tiktoken==0.5.2 in /usr/local/lib/python3.12/dist-packages (0.5.2)
# Requirement already satisfied: python-dotenv==1.0.0 in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.12.0) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.12.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.12.0) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.12.0) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai==1.12.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai==1.12.0) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.12/dist-packages (from openai==1.12.0) (4.15.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (1.4.0)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (2.32.4)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (0.133.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (0.41.0)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (7.9.4)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (3.10.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (1.24.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (1.39.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (0.60b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (1.78.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (9.1.4)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb==0.4.22) (5.2.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken==0.5.2) (2025.11.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai==1.12.0) (3.11)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb==0.4.22) (26.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb==0.4.22) (1.2.0)
# Requirement already satisfied: starlette>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.95.2->chromadb==0.4.22) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.95.2->chromadb==0.4.22) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.95.2->chromadb==0.4.22) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai==1.12.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai==1.12.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.12.0) (0.16.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb==0.4.22) (0.10)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.22) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.22) (5.29.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.22) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.2.0->chromadb==0.4.22) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.22) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.22) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.4.22) (1.39.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.60b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22) (0.60b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22) (0.60b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22) (0.60b1)
# Requirement already satisfied: opentelemetry-util-http==0.60b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22) (0.60b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation==0.60b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22) (1.17.3)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-asgi==0.60b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.4.22) (3.11.1)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog>=2.4.0->chromadb==0.4.22) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.12.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.12.0) (2.41.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28->chromadb==0.4.22) (3.4.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.13.2->chromadb==0.4.22) (1.4.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb==0.4.22) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb==0.4.22) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb==0.4.22) (13.9.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.22) (15.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.22) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.22) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.22) (1.3.0)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.4.22) (0.24.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.4.22) (3.23.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.9.0->chromadb==0.4.22) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.9.0->chromadb==0.4.22) (2.19.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb==0.4.22) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.22) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.9.0->chromadb==0.4.22) (0.1.2)

# %% [markdown]
# ### Load secrets
#
# If you run this code in Google Colab, save your OpenAI API key in the secrets and access it by

# %%
import os
import sys
from dotenv import load_dotenv

# Check if running in Google Colab
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    try:
        from google.colab import userdata  # type: ignore

        #os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
        #os.environ["ANTHROPIC_API_KEY"] = userdata.get("ANTHROPIC_API_KEY")
        os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
    except ModuleNotFoundError:
        pass
else:
    load_dotenv()

# %% [markdown]
# ### Load sample files
#
# This notebook uses sample Word and PDF files.
#
# When running the notebook on Google Colab, uncomment the code below to download the `datasets` directory from the Github repo.

# %%
import sys

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    # !git clone --no-checkout https://github.com/polzerdo55862/RAG-with-Python-Cookbook.git
    # %cd RAG-with-Python-Cookbook
    # !git sparse-checkout init --cone
    # !git sparse-checkout set datasets
    # !git checkout
    # !cp -r datasets /content/datasets
    print("\u2713 Datasets downloaded to /content/datasets")
else:
    print("\u26a0 Running locally. Using ../datasets/ directory")
# Out:
# Cloning into 'RAG-with-Python-Cookbook'...
# remote: Enumerating objects: 1657, done.
# remote: Counting objects: 100% (414/414), done.
# remote: Compressing objects: 100% (201/201), done.
# remote: Total 1657 (delta 278), reused 265 (delta 207), pack-reused 1243 (from 2)
# Receiving objects: 100% (1657/1657), 42.86 MiB | 15.91 MiB/s, done.
# Resolving deltas: 100% (946/946), done.
# /content/RAG-with-Python-Cookbook
# Your branch is up to date with 'origin/main'.
# ✓ Datasets downloaded to /content/datasets

# %% [markdown]
# ### Load secrets
#
# If you run this code in Google Colab, save your OpenAI API key in the secrets and access it by

# %%
import os

if IN_COLAB:
    from google.colab import userdata  # type: ignore

    api_key = userdata.get("OPENAI_API_KEY")

    if not api_key:
        raise ValueError("OPENAI_API_KEY not found in Colab Secrets")

    os.environ["OPENAI_API_KEY"] = api_key

# %% [markdown]
# ## Step 1: Text Chunking
#
# Split documents into smaller chunks with overlap to preserve context.

# %%
from pathlib import Path
import chromadb
from openai import OpenAI


def chunk_text(text, size=1000, overlap=200):
    chunks, start = [], 0
    while start < len(text):
        end = min(start + size, len(text))
        if end < len(text):
            bp = text.rfind("\n\n", start, end)
            if bp == -1:
                bp = text.rfind(". ", start, end)
            if bp > start:
                end = bp + 1
        chunk = text[start:end].strip()
        if chunk:
            chunks.append(chunk)
        start = end - overlap if end < len(text) else end
    return chunks


file_path = Path("./datasets/text_files/harry_potter_knowledge_base.txt")
text = file_path.read_text(encoding="utf-8")
chunks = chunk_text(text)

# %% [markdown]
# ## Step 2: Embed and Store in ChromaDB
#
# Generate embeddings and store them in a vector database.

# %%
import httpx # Add this import
client = OpenAI(http_client=httpx.Client())
embedding_model = "text-embedding-3-small"


def embed_and_store(chunks, db_path, collection_name):
    chroma = chromadb.PersistentClient(path=str(db_path))
    collection = chroma.get_or_create_collection(
        name=collection_name,
        metadata={"description": "Harry Potter knowledge base"},
    )

    embeddings = []
    for i in range(0, len(chunks), 100):
        batch = chunks[i : i + 100]
        res = client.embeddings.create(model=embedding_model, input=batch)
        embeddings.extend([x.embedding for x in res.data])

    collection.add(
        ids=[f"chunk_{i}" for i in range(len(chunks))],
        documents=chunks,
        embeddings=embeddings,
        metadatas=[{"chunk_index": i} for i in range(len(chunks))],
    )
    return collection


chroma_db_dir = Path("chroma_db")
collection = embed_and_store(chunks, chroma_db_dir, "harry_potter_kb")
collection
# Out:
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# ERROR:chromadb.telemetry.product.posthog:Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_5
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_6
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_7
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_8
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_9
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_10
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_11
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_12
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_13
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_14
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_15
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_16
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_17
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_18
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_19
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_20
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_21
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_22
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_23
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_24
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_25
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_26
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: chunk_27
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_0
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_1
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_2
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_3
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_4
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_5
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_6
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_7
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_8
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_9
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_10
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_11
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_12
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_13
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_14
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_15
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_16
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_17
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_18
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_19
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_20
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_21
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_22
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_23
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_24
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_25
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_26
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: chunk_27
# Collection(name=harry_potter_kb)

# %% [markdown]
# ## Step 3: Test Retrieval
#
# Test that the retrieval system finds relevant chunks for a given question.

# %%
def retrieve(question, top_k=3):
    q_emb = client.embeddings.create(
        model=embedding_model,
        input=question,
    ).data[0].embedding

    res = collection.query(
        query_embeddings=[q_emb],
        n_results=top_k,
        include=["documents"],
    )

    return res["documents"][0]


question = "Why did Uncle Vernon take the family to a hut in the middle of the sea?"
docs = retrieve(question)
docs
# Out:
# ["dozen, then by the hundred. They came through the chimney, through cracks in the door, even delivered by owls. Uncle Vernon tried everything to stop them, but the letters found Harry wherever he was.\n\nFinally, in a desperate attempt to escape the letters, Uncle Vernon drove the family to a hut on a rock in the middle of the sea. On the stroke of midnight on Harry's eleventh birthday, there was a tremendous bang on the door, and it was blasted open by Hagrid, the giant gamekeeper from Hogwarts. Hagrid was furious to discover that the Dursleys had never told Harry about his magical heritage, about his parents' true fate, or about his acceptance to Hogwarts School of Witchcraft and Wizardry.",
#  "Little Whinging, Surrey. There was no stamp, and when Harry turned it over, he saw a purple wax seal bearing a coat of arms with a lion, an eagle, a badger, and a snake surrounding a large letter H.\n\nBefore Harry could open it, Uncle Vernon snatched it away. After reading it, his face went from red to green faster than a traffic light, and he immediately decided that the family would move Harry out of the cupboard into Dudley's second bedroom. But the letters kept coming - by the dozen, then by the hundred. They came through the chimney, through cracks in the door, even delivered by owls. Uncle Vernon tried everything to stop them, but the letters found Harry wherever he was.",
#  "control their powers. Harry would learn about Transfiguration, Charms, Potions, the History of Magic, and much more. He would also learn to fly on broomsticks and play Quidditch, the wizarding sport.\n\nWhen Uncle Vernon tried to prevent Harry from going, declaring that he wouldn't pay for Harry to learn magic tricks, Hagrid revealed that Harry's parents had left him a fortune in the wizarding bank, Gringotts. Harry was actually quite wealthy and wouldn't need the Dursleys' money at all. This revelation, combined with Hagrid's obvious magical power (he gave Dudley a pig's tail when Vernon insulted Dumbledore), finally convinced the Dursleys to let Harry go.\n\n## Harry's Heritage and Destiny"]

# %% [markdown]
# ## Step 4: Test Generation
#
# Feed the retrieved documents and question to the LLM to generate an answer.

# %%
def answer(question, docs):
    context = "\n\n---\n\n".join(docs)
    prompt = f"""Answer the question using only the context below.

Context:
{context}

Question:
{question}

Answer:"""

    res = client.chat.completions.create(
        model="gpt-5-mini",
        messages=[{"role": "user", "content": prompt}],
    )

    return res.choices[0].message.content


question = "Why did Uncle Vernon take the family to a hut in the middle of the sea?"
docs = retrieve(question)
answer_text = answer(question, docs)
answer_text
# Out:
# 'Because dozens—then hundreds—of letters addressed to Harry kept arriving no matter what Vernon did, so he drove the family to a hut on a rock in the middle of the sea to escape the letters.'
